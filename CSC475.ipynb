# %%
import pandas as pd
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
seminar_data = pd.read_csv("CSC 475 Survey.csv")

# %%
seminar_data.head()
# Out:
#                     Timestamp  \
# 0   2025/10/16 1:12:40 PM EST
# 1  2025/10/23 12:06:34 PM EST
# 2  2025/10/23 12:06:57 PM EST
# 3  2025/10/23 12:08:29 PM EST
# 4  2025/10/23 12:09:12 PM EST
#
#   Please select the category of which you most identify with.  \
# 0                                            Student
# 1                                            Student
# 2                                            Faculty
# 3                                            Student
# 4                                            Student
#
#   Please select your area of study. (If you have multiple areas of study, please select all areas that you are involved in.)  \
# 0  STEM (Science, Technology, Engineering, Mathem...
# 1  STEM (Science, Technology, Engineering, Mathem...
# 2  STEM (Science, Technology, Engineering, Mathem...
# 3  STEM (Science, Technology, Engineering, Mathem...
# 4  STEM (Science, Technology, Engineering, Mathem...
#
# ...

# %%
seminar_data.shape
# Out:
# (24, 28)

# %%
seminar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 28 columns):
# ...

# %%
seminar_data.columns
# Out:
# Index(['Timestamp',
#        'Please select the category of which you most identify with.',
#        'Please select your area of study. (If you have multiple areas of study, please select all areas that you are involved in.)',
#        'How often do you intentionally use generative AI? ',
#        'Which generative AI do you typically use? (If none of the options listed apply to you, please select "Other".)',
#        'What is your broad use of generative AI?',
#        'What are your typical uses of generative AI in an academic or career setting?',
#        'Should students be allowed to use AI for their assignments and tests? Please rate your comfortability.',
#        'Should instructors be allowed to use AI for grading and creating assignments? Please rate your comfortability.',
#        'Using the options below, please select if you Agree or Disagree with the following prompt: "I feel confident in the accuracy of the output that generative AI provides."',
# ...

# %%
seminar_data = seminar_data.rename(columns={'Please select the category of which you most identify with.':'Identity', 'Please select your area of study. (If you have multiple areas of study, please select all areas that you are involved in.)':'Major(s)', 'How often do you intentionally use generative AI? ':'Frequency', 'Which generative AI do you typically use? (If none of the options listed apply to you, please select "Other".)':'Type of AI', 'What is your broad use of generative AI?':'Broad Usage', 'What are your typical uses of generative AI in an academic or career setting?':'Academic/Work Usage', 'Should students be allowed to use AI for their assignments and tests? Please rate your comfortability.':'Students Using AI', })

# %%
new_names ={
  "Timestamp": "Timestamp",
  "Please select the category of which you most identify with.": "Identity",
  "Please select your area of study. (If you have multiple areas of study, please select all areas that you are involved in.)": "Study",
  "How often do you use generative AI? ": "Frequency",
  'Which generative AI do you typically use? (If none of the options listed apply to you, please select the "Other".)': "Tools",
  "What is your broad use of generative AI?": "Use",
  "What are your typical uses of generative AI in an academic or career setting?": "AcademicUse",
  "Should students be allowed to use AI for their assignments and tests? Please rate your comfortability.": "StudentComfort",
  "Should instructors be allowed to use AI for grading and creating assignments? Please rate your comfortability.": "InstructorComfort",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I feel confident in the accuracy of the output that generative AI provides.\"": "Accuracy",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I plan on incorporating generative AI into my daily academic workload.\"": "AcademicPlans",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I plan on incorporating generative AI into my future career workload.\"": "CareerPlans",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"The use of generative AI in higher education is lowering the critical thinking skills of students.\"": "CriticalThinking",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"The skillful use of generative AI should be taught in higher education.\"": "TeachAI",
  "Please rate how you feel about the following statement: \"I would not be opposed to attending/teaching a course that explains how to skillfully use AI to its fullest advantage.\"": "CourseOpenness",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"Generative AI is going to be unavoidable in the future for most careers.\"": "Unavoidable",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I feel anxious about the growing capabilities of generative AI.\"": "AIAnxiety",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I have ethical concerns about the increasing use of generative AI in both academia and workforce.\"": "Ethics",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I am anxious that AI will make my career obsolete.\"": "CareerAnxiety",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I am anxious about the spread of misinformation due to generative AI.\"": "MisinfoAnxiety",
  "Using the options below, please select if you Agree or Disagree with the following prompt: \"I am anxious about the environment concerns that AI causes.\"": "EnviroAnxiety",
  "Do you think AI is biased? If so, how does that make you feel about it's increasing use in daily life?": "Bias",
  "Should the software companies that develop generative AI be regulated? If so, how and why?": "CompanyReg",
  "Should the consumers of generative AI be regulated? (e.g. Privacy Laws, Fair Use) If so, how and why? ": "ConsumerReg",
  "What tasks do you think AI is good at? What tasks do you think AI could improve on?": "Tasks",
  "Scenario: You are a pedestrian walking on the sidewalk. On the road, to your right, there is a self driving car making a right turn. On the cross walk, there is a couple walking their dog. The car does not recognize the couple on the cross walk and proceeds to hit them. Both individuals were seriously injured. \n\nWho should be held accountable for the injuries of those pedestrians? ": "CarScenario",
  "Scenario: A college student named is preparing for their senior art show. They use an AI image generator to create a series of digital portraits inspired by famous modern paintings. The AI model they use was trained on millions of online images, including copyrighted artworks, without the explicit permission of the artists or museums.\nThe student modifies the AI-generated portraits by adding their own personal, artistic touches. Their final pieces are displayed at the university gallery and shared online. The exhibition gains a lot of attention.\nA week later, one of the original artists whose painting was used in the AI’s training data contacts the student, claiming that their piece is too similar to his work and violates his copyright. The student argues that their artwork is protected under \"fair use\" because they transformed the original image using AI and their own edits.\nIs it ethical for the student to claim that the artwork is theirs and protected under \"fair use\"?": "ArtScenario",
  "Dr. Professor, a professor at a large university, teaches a graduate-level seminar on public policy. One of her students is known for being thoughtful but struggles with academic writing in English, their second language.\nFor the final project, students must write a 20-page research paper analyzing the impact of artificial intelligence on employment trends. The student uses a generative AI tool to help him organize his thoughts, summarize academic articles, and improve the clarity of their writing. They carefully check the AI’s work for accuracy and ensures that all cited sources are real and properly referenced.\nWhen the student submits his paper, Dr. Professor is impressed by its clarity and coherence, much more than their previous work. She begins to suspect that they might have relied too heavily on AI. University policy allows “limited” AI assistance for brainstorming or proofreading but prohibits AI-generated writing from being submitted as original work. \nShould Dr. Professor accuse the student of academic dishonesty and report the student to the Academic Dean?": "AcademicScenario"
}
seminar_data = seminar_data.rename(columns=new_names)

# %%
seminar_data.columns
# Out:
# Index(['Timestamp', 'Identity', 'Study', 'Frequency', 'Type of AI', 'Use',
#        'AcademicUse', 'StudentComfort', 'InstructorComfort', 'Accuracy',
#        'AcademicPlans', 'CareerPlans', 'CriticalThinking', 'TeachAI',
#        'CourseOpenness', 'Unavoidable', 'AIAnxiety', 'Ethics', 'CareerAnxiety',
#        'MisinfoAnxiety', 'EnviroAnxiety', 'Bias', 'CompanyReg', 'ConsumerReg',
#        'Tasks', 'CarScenario', 'ArtScenario', 'AcademicScenario'],
#       dtype='object')

# %%
seminar_data.head()
# Out:
#                     Timestamp Identity  \
# 0   2025/10/16 1:12:40 PM EST  Student
# 1  2025/10/23 12:06:34 PM EST  Student
# 2  2025/10/23 12:06:57 PM EST  Faculty
# 3  2025/10/23 12:08:29 PM EST  Student
# 4  2025/10/23 12:09:12 PM EST  Student
#
#                                                Study Frequency  \
# 0  STEM (Science, Technology, Engineering, Mathem...   Weekly.
# 1  STEM (Science, Technology, Engineering, Mathem...   Weekly.
# 2  STEM (Science, Technology, Engineering, Mathem...   Weekly.
# 3  STEM (Science, Technology, Engineering, Mathem...   Weekly.
# 4  STEM (Science, Technology, Engineering, Mathem...    Daily.
#
#                       Type of AI                 Use  \
# 0                         Claude                 NaN
# 1                        ChatGPT  Academic Learning.
# 2  ChatGPT;CoPilot;Claude;Gemini               Work.
# 3                 ChatGPT;Claude  Academic Learning.
# 4  ChatGPT;CoPilot;Claude;Gemini  Academic Learning.
#
# ...

# %%
# create a histogram of Frequency column

plt.figure(figsize=(10,6))
seminar_data['Frequency'].value_counts().plot(kind='barh')


# show percentage next to each bar with '%' sign
for index, value in enumerate(seminar_data['Frequency'].value_counts()):
    plt.text(value, index, f'{value} ({value/seminar_data.shape[0]*100:.1f}%)')


plt.title('Frequency of Generative AI Usage')
plt.ylabel('Frequency')
plt.xlabel('Number of Respondents')
plt.show()

# %%
seminar_data['Use']
# Out:
# 0                                                   NaN
# 1                                    Academic Learning.
# 2                                                 Work.
# 3                                    Academic Learning.
# 4                                    Academic Learning.
# 5                                                 Work.
# 6                                    Academic Learning.
# 7                                    Academic Learning.
# 8                                    Academic Learning.
# 9                                                 Work.
# 10                                   Academic Learning.
# 11                                   Academic Learning.
# 12                                   Academic Learning.
# 13                                                Work.
# 14                                   Academic Learning.
# 15                                   Academic Learning.
# 16           Academic Learning.;Work.;Personal Errands.
# ...

# %%
all_uses = []
for val in seminar_data['Use'].values: 
    
    if (type(val) != float) and (';' in val): 
        uses = val.split(';')
        for use in uses: 
            all_uses.append(use)
    else: 
        all_uses.append(val)

use_series = pd.Series(all_uses)

# %%
# Create a histogram of Use column 
plt.figure(figsize=(10,6))
use_series.value_counts().plot(kind='barh')
# show percentage next to each bar with '%' sign
for index, value in enumerate(use_series.value_counts()):
    plt.text(value, index, f'{value} ({value/seminar_data.shape[0]*100:.1f}%)')
plt.title('Broad Usage of Generative AI')
plt.ylabel('Usage')
plt.xlabel('Number of Respondents')
plt.tight_layout()
plt.show()

# %%
[val for val in seminar_data['AcademicUse'].values if ';' in val]
# Out:
# ['Searching for answers/researching questions.;Automating a task (Summarizing a document).;Helping with code development (debugging code, generating code).;Using it for educational purposes (creating a study guide, creating a quiz).',
#  'Content Creation: generating text/images/videos/music.;Searching for answers/researching questions.;Using it for educational purposes (creating a study guide, creating a quiz).;Lecture examples']

# %%
all_uses = []
for val in seminar_data['AcademicUse'].values: 
    
    if (type(val) != float) and (';' in val): 
        uses = val.split(';')
        for use in uses: 
            all_uses.append(use)
    else: 
        all_uses.append(val)

use_series = pd.Series(all_uses)

# %%
use_series
# Out:
# 0     Helping with code development (debugging code,...
# 1          Searching for answers/researching questions.
# 2     Content Creation: generating text/images/video...
# 3     Using it for educational purposes (creating a ...
# 4     Using it for educational purposes (creating a ...
# 5     Helping with code development (debugging code,...
# 6     Helping with code development (debugging code,...
# 7          Searching for answers/researching questions.
# 8          Searching for answers/researching questions.
# 9          Searching for answers/researching questions.
# 10    Helping with code development (debugging code,...
# 11         Searching for answers/researching questions.
# 12    Helping with code development (debugging code,...
# 13    Helping with code development (debugging code,...
# 14    Helping with code development (debugging code,...
# 15    Helping with code development (debugging code,...
# 16         Searching for answers/researching questions.
# ...

# %%
# Create a histogram of AcademicUse column
plt.figure(figsize=(10,6))
use_series.value_counts().plot(kind='barh')

# Add newlines after every 100 characters on the y tick labels
# Split long ytick values into multiple lines each of say 50 characters so that they fit better
ytickvalues = use_series.value_counts().index
newtickvals = [val.split('()')[0].split(':')[0].split('.')[0] for val in ytickvalues]
plt.yticks(ticks=range(len(ytickvalues)), labels=newtickvals)

# show percentage next to each bar with '%' sign
for index, value in enumerate(use_series.value_counts()):
    plt.text(value, index, f'{value} ({value/seminar_data.shape[0]*100:.1f}%)')
plt.title('Typical Uses of Generative AI in Academic/Work Setting')
plt.ylabel('Academic/Work Usage')
plt.xlabel('Number of Respondents')
plt.show()

# %%
def make_hbarplot(col_name):
    plt.figure(figsize=(10,6))
    seminar_data[col_name].value_counts().plot(kind='barh')
    # show percentage next to each bar with '%' sign
    for index, value in enumerate(seminar_data[col_name].value_counts()):
        plt.text(value, index, f'{value} ({value/seminar_data.shape[0]*100:.1f}%)')
    plt.title(f'Responses for {col_name}')
    plt.ylabel(col_name)
    plt.xlabel('Number of Respondents')
    plt.tight_layout()
    plt.savefig('images/'+col_name+'.png')
    plt.close()
    # plt.show()

for column in seminar_data.columns: 
    if column not in ['Timestamp', 'Identity', 'Study', 'Frequency', 'Tools', 'Use', 'AcademicUse']:
        make_hbarplot(column)
# Out:
# /var/folders/l9/y8y3rmys2sl93tzzph3dl7jw0000gr/T/ipykernel_46075/982758044.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /var/folders/l9/y8y3rmys2sl93tzzph3dl7jw0000gr/T/ipykernel_46075/982758044.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /var/folders/l9/y8y3rmys2sl93tzzph3dl7jw0000gr/T/ipykernel_46075/982758044.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /var/folders/l9/y8y3rmys2sl93tzzph3dl7jw0000gr/T/ipykernel_46075/982758044.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ...
